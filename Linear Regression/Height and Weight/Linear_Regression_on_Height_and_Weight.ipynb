# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('/content/SOCR-HeightWeight.csv')

# %%
Data.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           25000 non-null  int64
#  1   Height(Inches)  25000 non-null  float64
#  2   Weight(Pounds)  25000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 586.1 KB

# %%
Data.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
from sklearn.model_selection import train_test_split

# %%
X = Data[['Height(Inches)']]
Y = Data['Weight(Pounds)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
Prediction = LR.predict(X_test)

# %%
sns.scatterplot(x = Prediction, y = y_test, alpha = 0.2)
# Out:
# <Axes: ylabel='Weight(Pounds)'>

# %%
plt.scatter(X_test, y_test, color='b')
plt.plot(X_test,Prediction)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
import math

# %%
MAE = mean_absolute_error(y_test, Prediction)
MSE = mean_squared_error(y_test, Prediction)
RMSE = math.sqrt(MSE)

# %%
print("Mean Absolute Error: ",MAE)
print("Mean Squared Error: ",MSE)
print("Root Mean Squared Error: ",RMSE)
# Out:
# Mean Absolute Error:  8.073165906390226
# Mean Squared Error:  101.73966139367002
# Root Mean Squared Error:  10.086608022207962

# %%
r2 = r2_score(y_test, Prediction)
print(r2)
# Out:
# 0.26604732615405746

# %%
Data.corr()
# Out:
#                    Index  Height(Inches)  Weight(Pounds)
# Index           1.000000        0.009626       -0.007257
# Height(Inches)  0.009626        1.000000        0.502859
# Weight(Pounds) -0.007257        0.502859        1.000000

# %% [markdown]
# ##Conclusion

# %% [markdown]
# Due to less Correlation between Height and Weight(0.5), the r2 score is less(0.2). The model performance is weak.
