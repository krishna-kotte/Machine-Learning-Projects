# %% [markdown]
# Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Create DataFrame

# %%
Data = pd.read_csv('/content/Ecommerce Customers')

# %% [markdown]
# EDA

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
Data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
sns.scatterplot(x='Avg. Session Length', y= 'Yearly Amount Spent', data = Data, alpha= 0.5)
# Out:
# <Axes: xlabel='Avg. Session Length', ylabel='Yearly Amount Spent'>

# %%
sns.scatterplot(x='Time on App', y= 'Yearly Amount Spent', data = Data, alpha= 0.5)
# Out:
# <Axes: xlabel='Time on App', ylabel='Yearly Amount Spent'>

# %%
sns.scatterplot(x='Time on Website', y= 'Yearly Amount Spent', data = Data, alpha= 0.5)
# Out:
# <Axes: xlabel='Time on Website', ylabel='Yearly Amount Spent'>

# %%
sns.scatterplot(x='Length of Membership', y= 'Yearly Amount Spent', data = Data, alpha= 0.5)
# Out:
# <Axes: xlabel='Length of Membership', ylabel='Yearly Amount Spent'>

# %% [markdown]
# Pairplot to Visualize all numerical variable

# %%
sns.pairplot(Data)

# %% [markdown]
# Spliting Data for Training and Testing

# %%
from sklearn.model_selection import train_test_split

# %%
X = Data[['Avg. Session Length','Time on App','Time on Website','Length of Membership']]
Y = Data['Yearly Amount Spent']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=42)

# %% [markdown]
# Linear Regression Implementation

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction using Test Data

# %%
#to find the parameter values

LR.coef_
# Out:
# array([25.72425621, 38.59713548,  0.45914788, 61.67473243])

# %%
Prediction = LR.predict(X_test)

# %% [markdown]
# Visualizing the Prediction

# %%
sns.scatterplot(x = Prediction, y=y_test)
# Out:
# <Axes: ylabel='Yearly Amount Spent'>

# %% [markdown]
# Calculating Errors

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

# %%
MAE = mean_absolute_error(y_test, Prediction)
MSE = mean_squared_error(y_test, Prediction)
RMSE = math.sqrt(MSE)

# %%
print("Mean Absolute Error: ",MAE)
print("Mean Squared Error: ",MSE)
print("Root Mean Squared Error: ",RMSE)
# Out:
# Mean Absolute Error:  8.426091641432116
# Mean Squared Error:  103.91554136503333
# Root Mean Squared Error:  10.193897260863155
